# %% [markdown]
# ### Real Drug Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/s/ML_Projects/Medicine_Pharmaceuticals_PublicHealth/Drug_TreatmentData/Data/real_drug_dataset.csv")
df.head(15)
# Out:
#    Patient_ID  Age  Gender     Condition      Drug_Name  Dosage_mg  \
# 0       P0001   56    Male     Infection  Ciprofloxacin         50
# 1       P0002   69    Male  Hypertension     Metoprolol        500
# 2       P0003   46  Female    Depression      Bupropion        100
# 3       P0004   32    Male      Diabetes      Glipizide        850
# 4       P0005   60    Male    Depression      Bupropion        850
# 5       P0006   25  Female     Infection  Ciprofloxacin        850
# 6       P0007   78    Male      Diabetes      Glipizide        250
# 7       P0008   38    Male   Pain Relief    Paracetamol        100
# 8       P0009   56    Male    Depression   Escitalopram        850
# 9       P0010   75    Male      Diabetes      Metformin        850
# 10      P0011   36    Male    Depression      Bupropion         50
# 11      P0012   40  Female      Diabetes      Glipizide        500
# 12      P0013   28    Male  Hypertension     Amlodipine         50
# ...

# %% [markdown]
# ### Dataset Dimensions

# %%
print(f"\nData Frame Dimensions: {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# Data Frame Dimensions: 1000 rows and 9 columns

# %%
print(df.head())
# Out:
#   Patient_ID  Age  Gender     Condition      Drug_Name  Dosage_mg  \
# 0      P0001   56    Male     Infection  Ciprofloxacin         50
# 1      P0002   69    Male  Hypertension     Metoprolol        500
# 2      P0003   46  Female    Depression      Bupropion        100
# 3      P0004   32    Male      Diabetes      Glipizide        850
# 4      P0005   60    Male    Depression      Bupropion        850
#
#    Treatment_Duration_days     Side_Effects  Improvement_Score
# 0                        9           Nausea                8.5
# 1                       24        Tiredness                8.7
# 2                       25        Dry mouth                5.4
# 3                       44  Low blood sugar                6.4
# 4                       35          Anxiety                5.3

# %%
df.dtypes
# Out:
# Patient_ID                  object
# Age                          int64
# Gender                      object
# Condition                   object
# Drug_Name                   object
# Dosage_mg                    int64
# Treatment_Duration_days      int64
# Side_Effects                object
# Improvement_Score          float64
# dtype: object

# %%
df.isnull().any()
# Out:
# Patient_ID                 False
# Age                        False
# Gender                     False
# Condition                  False
# Drug_Name                  False
# Dosage_mg                  False
# Treatment_Duration_days    False
# Side_Effects               False
# Improvement_Score          False
# dtype: bool
